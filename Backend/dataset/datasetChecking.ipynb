# %%
import pandas as pd 

df = pd.read_csv('Retail_RFM_Final.csv')
df.head()
# Out:
#    Customer ID  Recency  Frequency  Monetary
# 0        12346      326         12  77556.46
# 1        12347        2          8   5633.32
# 2        12348       75          5   2019.40
# 3        12349       19          4   4428.69
# 4        12350      310          1    334.40
